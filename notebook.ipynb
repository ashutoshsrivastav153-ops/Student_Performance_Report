# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\DELL\Desktop\Student_Performance_Report\student_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   study_hours     88 non-null     int64
#  1   attendance      88 non-null     int64
#  2   previous_marks  88 non-null     int64
#  3   final_marks     88 non-null     int64
# dtypes: int64(4)
# memory usage: 2.9 KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     study_hours  attendance  previous_marks  final_marks
# 0             2          50              40           42
# 1             3          55              45           48
# 2             4          60              50           55
# 3             5          65              55           60
# 4             6          70              60           65
# ..          ...         ...             ...          ...
# 83            6          75              70           72
# 84            7          80              75           78
# 85            8          85              80           85
# 86            9          90              85           90
# 87           10          95              90           95
#
# [88 rows x 4 columns]>

# %%
X=df[['study_hours','attendance','previous_marks']]

# %%
Y=df['final_marks']

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
print("Model Run Successfully")
# Out:
# Model Run Successfully

# %%
input_data=[[5, 90, 80]]
predicted_marks=model.predict(input_data)   
print("Predicted Marks",predicted_marks[0])
# Out:
# Predicted Marks 82.72759718002693
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import r2_score
Y_pred=model.predict(X)
print("Accuracy (R2 Score)",r2_score(Y, Y_pred))
# Out:
# Accuracy (R2 Score) 0.9967307415509539

# %%
import pandas as pd
plt.scatter(df['study_hours'], df['final_marks'])
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.title('Study Hours vs Marks')
plt.show()

# %%
df['results']=df['previous_marks'].apply(lambda x: 'Pass' if x>=50 else 'Fail')

# %%
import streamlit as st
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd

# Load data
df = pd.read_csv('C:\\Users\\DELL\\Desktop\\Student_Performance_Report\\student_data.csv')

X = df[['study_hours','attendance','previous_marks']]
y = df['final_marks']

model = LinearRegression()
model.fit(X, y)

st.title("Student Performance Predictor")

study_hours = st.slider("Study Hours", 0, 12)
attendance = st.slider("Attendance %", 0, 100)
previous_marks = st.slider("Previous Marks", 0, 100)

if st.button("Predict"):
    input_data = np.array([[study_hours, attendance, previous_marks]])
    prediction = model.predict(input_data)
    st.success(f"Predicted Marks: {prediction[0]:.2f}")
# Out:
# 2026-03-17 15:26:31.261 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 15:26:31.841
# ...
#   command:
#
#     streamlit run c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-03-17 15:26:31.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 15:26:31.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 15:26:31.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 15:26:31.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-17 15:26:31.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
